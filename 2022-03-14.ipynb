# %%
know_seq_values={0:0,1:1}
def fib(n):
    print(f"Fib({n}) is called.")
    if n in know_seq_values:
        return know_seq_values[n]
    ans = fib(n - 1) + fib(n - 2)
    know_seq_values[n] = ans
    print(f"Fib({n}) is stored.")
print(fib(40))
# Out:
# Fib(40) is called.
# Fib(39) is called.
# Fib(38) is called.
# Fib(37) is called.
# Fib(36) is called.
# Fib(35) is called.
# Fib(34) is called.
# Fib(33) is called.
# Fib(32) is called.
# Fib(31) is called.
# Fib(30) is called.
# Fib(29) is called.
# Fib(28) is called.
# Fib(27) is called.
# Fib(26) is called.
# Fib(25) is called.
# Fib(24) is called.
# Fib(23) is called.
# Fib(22) is called.
# Fib(21) is called.
# Fib(20) is called.
# Fib(19) is called.
# Fib(18) is called.
# Fib(17) is called.
# Fib(16) is called.
# Fib(15) is called.
# Fib(14) is called.
# Fib(13) is called.
# Fib(12) is called.
# Fib(11) is called.
# Fib(10) is called.
# Fib(9) is called.
# Fib(8) is called.
# Fib(7) is called.
# Fib(6) is called.
# Fib(5) is called.
# Fib(4) is called.
# Fib(3) is called.
# Fib(2) is called.
# Fib(1) is called.
# Fib(0) is called.
# Fib(2) is stored.
# Fib(1) is called.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-e12b157466cc> in <module>
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
# ---> 10 print(fib(40))
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# <ipython-input-4-e12b157466cc> in fib(n)
#       5     if n in know_seq_values:
#       6         return know_seq_values[n]
# ----> 7     ans = fib(n - 1) + fib(n - 2)
#       8     know_seq_values[n] = ans
#       9     print(f"Fib({n}) is stored.")
#
# TypeError: unsupported operand type(s) for +: 'NoneType' and 'int'
